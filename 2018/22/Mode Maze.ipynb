# %% [markdown]
# ## Day 22: Mode Maze
#
# https://adventofcode.com/2018/day/22
#
# ### Part 1
#
# Follow the instructions, creating yet another dictionary with coordinates as keys.

# %%
def erosion_level(depth, target_x, target_y):
    erosion = {(0, 0): 0, (target_x, target_y): 0}

    for x in range(1, target_x + 1):
        erosion[(x, 0)] = (x * 16807 + depth) % 20183
    for y in range(1, target_y + 1):
        erosion[(0, y)] = (y * 48271 + depth) % 20183

    for x in range(1, target_x + 1):
        for y in range(1, target_y + 1):
            if x != target_x or y != target_y:
                erosion[(x, y)] = (erosion[(x - 1, y)] * erosion[(x, y - 1)] + depth) % 20183
                
    return erosion

# %%
test_erosion = erosion_level(510, 10, 10)

# %%
def erosion_types(depth, max_x, max_y):
    el = erosion_level(depth, max_x, max_y)
    return {k: el[k] % 3 for k in el}

# %%
test_erosion_types = erosion_types(510, 10, 10)

# %%
sum(test_erosion_types.values())
# Out:
# 114

# %%
problem_erosion = erosion_types(10689, 11, 722)

# %%
sum(problem_erosion.values())
# Out:
# 8575

# %% [markdown]
# ### Part 2
#
# Use A\* to find the path with Manhattan distance to the target as heuristic. Valid moves are either moving to a neighbouring square where the current equipment will still be appropriate or changing equipment to another type that's appropriate for the current square.
#
# The erosion levels can go out of the bounds of the target so convert to a class where the values are lazily evaluated.

# %%
class Erosion:
    def __init__(self, depth, target_x, target_y):
        self.depth = depth
        self.erosion_level = {(0, 0): 0, (target_x, target_y): 0}
        
    def erosion_l(self, coordinates):
        if coordinates in self.erosion_level:
            return self.erosion_level[coordinates] 
        
        x, y = coordinates
        if y == 0:
            el = (x * 16807 + self.depth) % 20183
        elif x == 0:
            el = (y * 48271 + self.depth) % 20183
        else:
            el = (self.erosion_l((x - 1, y)) * self.erosion_l((x, y - 1)) 
                  + self.depth) % 20183
        self.erosion_level[coordinates] = el
        return el 
    
    def erosion(self, coordinates):
        return self.erosion_l(coordinates) % 3


e = Erosion(510, 10, 10)
sum(e.erosion((x, y)) for x in range(11) for y in range(11))
# Out:
# 114

# %%
from heapq import heappop, heappush


def manhattan_neighbours(coordinates):
    x, y = coordinates
        
    for d in (-1, 1):
        if x + d >= 0:
            yield (x + d, y)
        if y + d >= 0:
            yield (x, y + d)
            
                
def manhattan_distance(coordinates_1, coordinates_2):
    x1, y1 = coordinates_1
    x2, y2 = coordinates_2
    return abs(x1 - x2) + abs(y1 - y2)


def get_path(paths, state):
    if state is None:
        return []
    else:
        return get_path(paths, paths[state]) + [state]
    
    
def quickest_path(depth, target_x, target_y):
    equipment = {0: ['torch', 'climbing gear'],
                 1: ['climbing gear', 'neither'],
                 2: ['torch', 'neither']}
    
    erosion = Erosion(depth, target_x, target_y)
    
                
    def valid_moves(state):
        coordinates, gear = state
        
        for new_gear in equipment[erosion.erosion(coordinates)]:
            if new_gear != gear:
                yield (coordinates, new_gear)
        
        for new_location in manhattan_neighbours(coordinates):
            if gear in equipment[erosion.erosion(new_location)]:
                yield (new_location, gear)
                
                
    def time_taken(from_state, to_state):
        if from_state[1] != to_state[1]:
            return 7
        else:
            return 1
                
                
    start_state = ((0, 0), 'torch')
    queue = [(manhattan_distance((0, 0), (target_x, target_y)), start_state)]
    time_to = {start_state: 0}
    # In case we want to reconstruct the path
    previous = {start_state: None}
    
    while queue:
        _, current_state = heappop(queue)
        
        for next_state in valid_moves(current_state):
            time_to_next = time_to[current_state] + time_taken(current_state, next_state)
            
            if next_state not in time_to or time_to_next < time_to[next_state]:
                time_to[next_state] = time_to_next
                previous[next_state] = current_state
                
                if next_state == ((target_x, target_y), 'torch'):
                    return time_to_next, get_path(previous, next_state)
                 
                heappush(queue, 
                         (time_to_next + manhattan_distance(next_state[0], 
                                                            (target_x, target_y)),
                          next_state))
                
    return None

# %%
quickest_path(510, 10, 10)
# Out:
# (45,
#  [((0, 0), 'torch'),
#   ((0, 1), 'torch'),
#   ((1, 1), 'torch'),
#   ((1, 1), 'neither'),
#   ((2, 1), 'neither'),
#   ((3, 1), 'neither'),
#   ((4, 1), 'neither'),
#   ((4, 1), 'climbing gear'),
#   ((4, 2), 'climbing gear'),
#   ((4, 3), 'climbing gear'),
#   ((4, 4), 'climbing gear'),
#   ((4, 5), 'climbing gear'),
#   ((4, 6), 'climbing gear'),
#   ((4, 7), 'climbing gear'),
#   ((4, 8), 'climbing gear'),
#   ((4, 9), 'climbing gear'),
#   ((5, 9), 'climbing gear'),
#   ((5, 10), 'climbing gear'),
#   ((5, 11), 'climbing gear'),
#   ((6, 11), 'climbing gear'),
#   ((6, 12), 'climbing gear'),
#   ((7, 12), 'climbing gear'),
#   ((8, 12), 'climbing gear'),
#   ((8, 11), 'climbing gear'),
#   ((8, 10), 'climbing gear'),
#   ((9, 10), 'climbing gear'),
#   ((10, 10), 'climbing gear'),
#   ((10, 10), 'torch')])

# %%
# %time quickest_path(10689, 11, 722)
# Out:
# CPU times: user 3.47 s, sys: 36.3 ms, total: 3.5 s
# Wall time: 3.5 s
# (999,
#  [((0, 0), 'torch'),
#   ((0, 1), 'torch'),
#   ((1, 1), 'torch'),
#   ((1, 2), 'torch'),
#   ((1, 3), 'torch'),
#   ((2, 3), 'torch'),
#   ((2, 4), 'torch'),
#   ((2, 5), 'torch'),
#   ((3, 5), 'torch'),
#   ((3, 6), 'torch'),
#   ((3, 7), 'torch'),
#   ((3, 7), 'neither'),
#   ((3, 8), 'neither'),
#   ((3, 9), 'neither'),
#   ((3, 10), 'neither'),
#   ((3, 11), 'neither'),
#   ((3, 12), 'neither'),
#   ((3, 13), 'neither'),
#   ((3, 14), 'neither'),
#   ((2, 14), 'neither'),
#   ((2, 15), 'neither'),
#   ((2, 16), 'neither'),
#   ((1, 16), 'neither'),
#   ((1, 17), 'neither'),
#   ((1, 18), 'neither'),
#   ((1, 19), 'neither'),
#   ((2, 19), 'neither'),
#   ((2, 20), 'neither'),
#   ((2, 21), 'neither'),
#   ((2, 22), 'neither'),
#   ((2, 23), 'neither'),
#   ((2, 23), 'climbing gear'),
#   ((2, 24), 'climbing gear'),
#   ((1, 24), 'climbing gear'),
#   ((1, 25), 'climbing gear'),
#   ((1, 26), 'climbing gear'),
#   ((1, 27), 'climbing gear'),
#   ((1, 28), 'climbing gear'),
#   ((1, 29), 'climbing gear'),
#   ((2, 29), 'climbing gear'),
#   ((2, 30), 'climbing gear'),
#   ((3, 30), 'climbing gear'),
#   ((4, 30), 'climbing gear'),
#   ((4, 31), 'climbing gear'),
#   ((5, 31), 'climbing gear'),
#   ((6, 31), 'climbing gear'),
#   ((6, 32), 'climbing gear'),
#   ((6, 33), 'climbing gear'),
#   ((7, 33), 'climbing gear'),
#   ((7, 34), 'climbing gear'),
#   ((7, 35), 'climbing gear'),
#   ((7, 36), 'climbing gear'),
#   ((6, 36), 'climbing gear'),
#   ((5, 36), 'climbing gear'),
#   ((4, 36), 'climbing gear'),
#   ((4, 37), 'climbing gear'),
#   ((3, 37), 'climbing gear'),
#   ((3, 38), 'climbing gear'),
#   ((3, 39), 'climbing gear'),
#   ((3, 40), 'climbing gear'),
#   ((3, 41), 'climbing gear'),
#   ((4, 41), 'climbing gear'),
#   ((5, 41), 'climbing gear'),
#   ((5, 42), 'climbing gear'),
#   ((5, 43), 'climbing gear'),
#   ((5, 44), 'climbing gear'),
#   ((5, 45), 'climbing gear'),
#   ((5, 46), 'climbing gear'),
#   ((5, 47), 'climbing gear'),
#   ((6, 47), 'climbing gear'),
#   ((6, 48), 'climbing gear'),
#   ((6, 49), 'climbing gear'),
#   ((6, 50), 'climbing gear'),
#   ((6, 51), 'climbing gear'),
#   ((7, 51), 'climbing gear'),
#   ((7, 52), 'climbing gear'),
#   ((7, 53), 'climbing gear'),
#   ((7, 54), 'climbing gear'),
#   ((8, 54), 'climbing gear'),
#   ((8, 55), 'climbing gear'),
#   ((8, 56), 'climbing gear'),
#   ((8, 57), 'climbing gear'),
#   ((8, 58), 'climbing gear'),
#   ((8, 59), 'climbing gear'),
#   ((9, 59), 'climbing gear'),
#   ((9, 60), 'climbing gear'),
#   ((10, 60), 'climbing gear'),
#   ((10, 61), 'climbing gear'),
#   ((10, 62), 'climbing gear'),
#   ((10, 63), 'climbing gear'),
#   ((10, 64), 'climbing gear'),
#   ((10, 65), 'climbing gear'),
#   ((10, 66), 'climbing gear'),
#   ((10, 67), 'climbing gear'),
#   ((10, 68), 'climbing gear'),
#   ((10, 69), 'climbing gear'),
#   ((10, 70), 'climbing gear'),
#   ((10, 71), 'climbing gear'),
#   ((10, 72), 'climbing gear'),
#   ((10, 73), 'climbing gear'),
#   ((10, 74), 'climbing gear'),
#   ((10, 75), 'climbing gear'),
#   ((10, 76), 'climbing gear'),
#   ((10, 77), 'climbing gear'),
#   ((10, 78), 'climbing gear'),
#   ((10, 79), 'climbing gear'),
#   ((11, 79), 'climbing gear'),
#   ((11, 80), 'climbing gear'),
#   ((11, 81), 'climbing gear'),
#   ((11, 82), 'climbing gear'),
#   ((11, 83), 'climbing gear'),
#   ((11, 84), 'climbing gear'),
#   ((11, 85), 'climbing gear'),
#   ((10, 85), 'climbing gear'),
#   ((10, 86), 'climbing gear'),
#   ((10, 87), 'climbing gear'),
#   ((10, 88), 'climbing gear'),
#   ((10, 89), 'climbing gear'),
#   ((10, 90), 'climbing gear'),
#   ((10, 91), 'climbing gear'),
#   ((10, 92), 'climbing gear'),
#   ((11, 92), 'climbing gear'),
#   ((12, 92), 'climbing gear'),
#   ((13, 92), 'climbing gear'),
#   ((14, 92), 'climbing gear'),
#   ((14, 93), 'climbing gear'),
#   ((15, 93), 'climbing gear'),
#   ((15, 94), 'climbing gear'),
#   ((15, 95), 'climbing gear'),
#   ((15, 96), 'climbing gear'),
#   ((15, 97), 'climbing gear'),
#   ((15, 98), 'climbing gear'),
#   ((15, 99), 'climbing gear'),
#   ((16, 99), 'climbing gear'),
#   ((16, 100), 'climbing gear'),
#   ((16, 101), 'climbing gear'),
#   ((17, 101), 'climbing gear'),
#   ((17, 102), 'climbing gear'),
#   ((18, 102), 'climbing gear'),
#   ((18, 103), 'climbing gear'),
#   ((18, 104), 'climbing gear'),
#   ((18, 105), 'climbing gear'),
#   ((17, 105), 'climbing gear'),
#   ((16, 105), 'climbing gear'),
#   ((15, 105), 'climbing gear'),
#   ((15, 106), 'climbing gear'),
#   ((15, 107), 'climbing gear'),
#   ((15, 108), 'climbing gear'),
#   ((15, 109), 'climbing gear'),
#   ((15, 110), 'climbing gear'),
#   ((15, 111), 'climbing gear'),
#   ((15, 112), 'climbing gear'),
#   ((14, 112), 'climbing gear'),
#   ((14, 113), 'climbing gear'),
#   ((14, 114), 'climbing gear'),
#   ((14, 115), 'climbing gear'),
#   ((14, 116), 'climbing gear'),
#   ((14, 117), 'climbing gear'),
#   ((14, 118), 'climbing gear'),
#   ((14, 119), 'climbing gear'),
#   ((14, 120), 'climbing gear'),
#   ((15, 120), 'climbing gear'),
#   ((15, 121), 'climbing gear'),
#   ((15, 122), 'climbing gear'),
#   ((14, 122), 'climbing gear'),
#   ((14, 123), 'climbing gear'),
#   ((14, 124), 'climbing gear'),
#   ((14, 125), 'climbing gear'),
#   ((14, 126), 'climbing gear'),
#   ((14, 127), 'climbing gear'),
#   ((14, 128), 'climbing gear'),
#   ((14, 129), 'climbing gear'),
#   ((14, 130), 'climbing gear'),
#   ((13, 130), 'climbing gear'),
#   ((13, 131), 'climbing gear'),
#   ((12, 131), 'climbing gear'),
#   ((12, 132), 'climbing gear'),
#   ((12, 133), 'climbing gear'),
#   ((12, 134), 'climbing gear'),
#   ((12, 135), 'climbing gear'),
#   ((12, 136), 'climbing gear'),
#   ((13, 136), 'climbing gear'),
#   ((14, 136), 'climbing gear'),
#   ((15, 136), 'climbing gear'),
#   ((15, 137), 'climbing gear'),
#   ((15, 138), 'climbing gear'),
#   ((15, 139), 'climbing gear'),
#   ((16, 139), 'climbing gear'),
#   ((17, 139), 'climbing gear'),
#   ((18, 139), 'climbing gear'),
#   ((18, 140), 'climbing gear'),
#   ((18, 141), 'climbing gear'),
#   ((18, 142), 'climbing gear'),
#   ((19, 142), 'climbing gear'),
#   ((19, 143), 'climbing gear'),
#   ((20, 143), 'climbing gear'),
#   ((20, 144), 'climbing gear'),
#   ((20, 145), 'climbing gear'),
#   ((20, 146), 'climbing gear'),
#   ((20, 147), 'climbing gear'),
#   ((20, 148), 'climbing gear'),
#   ((20, 149), 'climbing gear'),
#   ((21, 149), 'climbing gear'),
#   ((21, 150), 'climbing gear'),
#   ((22, 150), 'climbing gear'),
#   ((22, 151), 'climbing gear'),
#   ((23, 151), 'climbing gear'),
#   ((24, 151), 'climbing gear'),
#   ((24, 152), 'climbing gear'),
#   ((25, 152), 'climbing gear'),
#   ((25, 153), 'climbing gear'),
#   ((25, 154), 'climbing gear'),
#   ((25, 155), 'climbing gear'),
#   ((25, 156), 'climbing gear'),
#   ((25, 157), 'climbing gear'),
#   ((25, 158), 'climbing gear'),
#   ((24, 158), 'climbing gear'),
#   ((24, 159), 'climbing gear'),
#   ((24, 160), 'climbing gear'),
#   ((24, 161), 'climbing gear'),
#   ((24, 162), 'climbing gear'),
#   ((24, 163), 'climbing gear'),
#   ((24, 164), 'climbing gear'),
#   ((24, 165), 'climbing gear'),
#   ((24, 166), 'climbing gear'),
#   ((24, 167), 'climbing gear'),
#   ((24, 168), 'climbing gear'),
#   ((24, 169), 'climbing gear'),
#   ((25, 169), 'climbing gear'),
#   ((25, 170), 'climbing gear'),
#   ((25, 171), 'climbing gear'),
#   ((24, 171), 'climbing gear'),
#   ((24, 172), 'climbing gear'),
#   ((23, 172), 'climbing gear'),
#   ((23, 173), 'climbing gear'),
#   ((23, 174), 'climbing gear'),
#   ((23, 175), 'climbing gear'),
#   ((23, 176), 'climbing gear'),
#   ((23, 177), 'climbing gear'),
#   ((23, 178), 'climbing gear'),
#   ((23, 179), 'climbing gear'),
#   ((22, 179), 'climbing gear'),
#   ((22, 180), 'climbing gear'),
#   ((22, 181), 'climbing gear'),
#   ((22, 182), 'climbing gear'),
#   ((22, 183), 'climbing gear'),
#   ((22, 184), 'climbing gear'),
#   ((22, 185), 'climbing gear'),
#   ((22, 186), 'climbing gear'),
#   ((22, 187), 'climbing gear'),
#   ((22, 187), 'neither'),
#   ((22, 188), 'neither'),
#   ((22, 189), 'neither'),
#   ((22, 190), 'neither'),
#   ((22, 191), 'neither'),
#   ((22, 192), 'neither'),
#   ((23, 192), 'neither'),
#   ((23, 193), 'neither'),
#   ((23, 194), 'neither'),
#   ((23, 195), 'neither'),
#   ((23, 196), 'neither'),
#   ((23, 197), 'neither'),
#   ((22, 197), 'neither'),
#   ((22, 198), 'neither'),
#   ((22, 199), 'neither'),
#   ((21, 199), 'neither'),
#   ((21, 200), 'neither'),
#   ((21, 201), 'neither'),
#   ((20, 201), 'neither'),
#   ((20, 202), 'neither'),
#   ((20, 203), 'neither'),
#   ((21, 203), 'neither'),
#   ((21, 204), 'neither'),
#   ((21, 205), 'neither'),
#   ((20, 205), 'neither'),
#   ((20, 206), 'neither'),
#   ((20, 207), 'neither'),
#   ((20, 208), 'neither'),
#   ((20, 209), 'neither'),
#   ((20, 210), 'neither'),
#   ((20, 211), 'neither'),
#   ((19, 211), 'neither'),
#   ((18, 211), 'neither'),
#   ((18, 212), 'neither'),
#   ((17, 212), 'neither'),
#   ((17, 213), 'neither'),
#   ((17, 214), 'neither'),
#   ((17, 215), 'neither'),
#   ((17, 216), 'neither'),
#   ((17, 217), 'neither'),
#   ((17, 218), 'neither'),
#   ((17, 219), 'neither'),
#   ((17, 220), 'neither'),
#   ((17, 220), 'torch'),
#   ((17, 221), 'torch'),
#   ((17, 222), 'torch'),
#   ((17, 223), 'torch'),
#   ((17, 224), 'torch'),
#   ((17, 225), 'torch'),
#   ((17, 226), 'torch'),
#   ((17, 227), 'torch'),
#   ((16, 227), 'torch'),
#   ((16, 228), 'torch'),
#   ((16, 229), 'torch'),
#   ((16, 230), 'torch'),
#   ((16, 231), 'torch'),
#   ((16, 232), 'torch'),
#   ((16, 233), 'torch'),
#   ((16, 234), 'torch'),
#   ((16, 235), 'torch'),
#   ((16, 236), 'torch'),
#   ((16, 237), 'torch'),
#   ((16, 238), 'torch'),
#   ((16, 239), 'torch'),
#   ((16, 240), 'torch'),
#   ((16, 241), 'torch'),
#   ((15, 241), 'torch'),
#   ((15, 242), 'torch'),
#   ((15, 243), 'torch'),
#   ((15, 244), 'torch'),
#   ((15, 245), 'torch'),
#   ((15, 246), 'torch'),
#   ((15, 247), 'torch'),
#   ((15, 248), 'torch'),
#   ((15, 249), 'torch'),
#   ((16, 249), 'torch'),
#   ((16, 250), 'torch'),
#   ((16, 251), 'torch'),
#   ((16, 252), 'torch'),
#   ((16, 253), 'torch'),
#   ((16, 254), 'torch'),
#   ((16, 255), 'torch'),
#   ((15, 255), 'torch'),
#   ((15, 256), 'torch'),
#   ((15, 257), 'torch'),
#   ((15, 258), 'torch'),
#   ((15, 259), 'torch'),
#   ((14, 259), 'torch'),
#   ((14, 260), 'torch'),
#   ((13, 260), 'torch'),
#   ((13, 261), 'torch'),
#   ((13, 262), 'torch'),
#   ((13, 263), 'torch'),
#   ((13, 264), 'torch'),
#   ((13, 265), 'torch'),
#   ((13, 265), 'neither'),
#   ((13, 266), 'neither'),
#   ((13, 267), 'neither'),
#   ((13, 268), 'neither'),
#   ((13, 269), 'neither'),
#   ((13, 270), 'neither'),
#   ((13, 271), 'neither'),
#   ((13, 272), 'neither'),
#   ((14, 272), 'neither'),
#   ((15, 272), 'neither'),
#   ((15, 273), 'neither'),
#   ((15, 274), 'neither'),
#   ((14, 274), 'neither'),
#   ((14, 275), 'neither'),
#   ((14, 276), 'neither'),
#   ((14, 277), 'neither'),
#   ((14, 278), 'neither'),
#   ((14, 279), 'neither'),
#   ((14, 280), 'neither'),
#   ((14, 281), 'neither'),
#   ((14, 282), 'neither'),
#   ((13, 282), 'neither'),
#   ((13, 283), 'neither'),
#   ((13, 284), 'neither'),
#   ((13, 285), 'neither'),
#   ((13, 286), 'neither'),
#   ((13, 287), 'neither'),
#   ((13, 288), 'neither'),
#   ((13, 289), 'neither'),
#   ((13, 290), 'neither'),
#   ((14, 290), 'neither'),
#   ((14, 291), 'neither'),
#   ((14, 292), 'neither'),
#   ((15, 292), 'neither'),
#   ((15, 293), 'neither'),
#   ((15, 294), 'neither'),
#   ((15, 295), 'neither'),
#   ((15, 296), 'neither'),
#   ((15, 297), 'neither'),
#   ((15, 298), 'neither'),
#   ((15, 299), 'neither'),
#   ((15, 300), 'neither'),
#   ((14, 300), 'neither'),
#   ((14, 300), 'climbing gear'),
#   ((14, 301), 'climbing gear'),
#   ((14, 302), 'climbing gear'),
#   ((13, 302), 'climbing gear'),
#   ((13, 303), 'climbing gear'),
#   ((13, 304), 'climbing gear'),
#   ((13, 305), 'climbing gear'),
#   ((13, 306), 'climbing gear'),
#   ((13, 307), 'climbing gear'),
#   ((13, 308), 'climbing gear'),
#   ((13, 309), 'climbing gear'),
#   ((13, 310), 'climbing gear'),
#   ((14, 310), 'climbing gear'),
#   ((14, 311), 'climbing gear'),
#   ((14, 312), 'climbing gear'),
#   ((14, 313), 'climbing gear'),
#   ((14, 314), 'climbing gear'),
#   ((14, 315), 'climbing gear'),
#   ((14, 316), 'climbing gear'),
#   ((14, 317), 'climbing gear'),
#   ((14, 318), 'climbing gear'),
#   ((14, 319), 'climbing gear'),
#   ((14, 320), 'climbing gear'),
#   ((14, 321), 'climbing gear'),
#   ((14, 322), 'climbing gear'),
#   ((14, 323), 'climbing gear'),
#   ((14, 324), 'climbing gear'),
#   ((14, 325), 'climbing gear'),
#   ((14, 326), 'climbing gear'),
#   ((15, 326), 'climbing gear'),
#   ((16, 326), 'climbing gear'),
#   ((17, 326), 'climbing gear'),
#   ((17, 327), 'climbing gear'),
#   ((18, 327), 'climbing gear'),
#   ((18, 328), 'climbing gear'),
#   ((18, 329), 'climbing gear'),
#   ((17, 329), 'climbing gear'),
#   ((17, 330), 'climbing gear'),
#   ((17, 331), 'climbing gear'),
#   ((17, 332), 'climbing gear'),
#   ((17, 333), 'climbing gear'),
#   ((17, 334), 'climbing gear'),
#   ((17, 335), 'climbing gear'),
#   ((17, 336), 'climbing gear'),
#   ((17, 337), 'climbing gear'),
#   ((17, 338), 'climbing gear'),
#   ((17, 339), 'climbing gear'),
#   ((17, 340), 'climbing gear'),
#   ((18, 340), 'climbing gear'),
#   ((18, 341), 'climbing gear'),
#   ((19, 341), 'climbing gear'),
#   ((19, 342), 'climbing gear'),
#   ((19, 343), 'climbing gear'),
#   ((20, 343), 'climbing gear'),
#   ((20, 344), 'climbing gear'),
#   ((20, 345), 'climbing gear'),
#   ((20, 346), 'climbing gear'),
#   ((20, 347), 'climbing gear'),
#   ((20, 348), 'climbing gear'),
#   ((20, 349), 'climbing gear'),
#   ((20, 350), 'climbing gear'),
#   ((21, 350), 'climbing gear'),
#   ((21, 351), 'climbing gear'),
#   ((21, 351), 'torch'),
#   ((21, 352), 'torch'),
#   ((21, 353), 'torch'),
#   ((21, 354), 'torch'),
#   ((21, 355), 'torch'),
#   ((21, 356), 'torch'),
#   ((21, 357), 'torch'),
#   ((21, 358), 'torch'),
#   ((21, 359), 'torch'),
#   ((20, 359), 'torch'),
#   ((20, 360), 'torch'),
#   ((20, 361), 'torch'),
#   ((21, 361), 'torch'),
#   ((21, 362), 'torch'),
#   ((21, 363), 'torch'),
#   ((21, 364), 'torch'),
#   ((21, 365), 'torch'),
#   ((21, 366), 'torch'),
#   ((21, 367), 'torch'),
#   ((21, 368), 'torch'),
#   ((21, 369), 'torch'),
#   ((21, 370), 'torch'),
#   ((21, 371), 'torch'),
#   ((22, 371), 'torch'),
#   ((22, 372), 'torch'),
#   ((22, 373), 'torch'),
#   ((21, 373), 'torch'),
#   ((21, 374), 'torch'),
#   ((21, 375), 'torch'),
#   ((21, 376), 'torch'),
#   ((21, 377), 'torch'),
#   ((21, 378), 'torch'),
#   ((21, 379), 'torch'),
#   ((20, 379), 'torch'),
#   ((20, 380), 'torch'),
#   ((20, 381), 'torch'),
#   ((19, 381), 'torch'),
#   ((18, 381), 'torch'),
#   ((17, 381), 'torch'),
#   ((17, 382), 'torch'),
#   ((17, 383), 'torch'),
#   ((17, 384), 'torch'),
#   ((17, 385), 'torch'),
#   ((17, 386), 'torch'),
#   ((17, 387), 'torch'),
#   ((17, 388), 'torch'),
#   ((17, 389), 'torch'),
#   ((17, 390), 'torch'),
#   ((16, 390), 'torch'),
#   ((16, 391), 'torch'),
#   ((15, 391), 'torch'),
#   ((14, 391), 'torch'),
#   ((14, 392), 'torch'),
#   ((14, 393), 'torch'),
#   ((14, 394), 'torch'),
#   ((14, 394), 'neither'),
#   ((14, 395), 'neither'),
#   ((14, 396), 'neither'),
#   ((14, 397), 'neither'),
#   ((14, 398), 'neither'),
#   ((14, 399), 'neither'),
#   ((14, 400), 'neither'),
#   ((14, 401), 'neither'),
#   ((14, 402), 'neither'),
#   ((14, 403), 'neither'),
#   ((14, 404), 'neither'),
#   ((14, 405), 'neither'),
#   ((14, 406), 'neither'),
#   ((14, 407), 'neither'),
#   ((14, 408), 'neither'),
#   ((15, 408), 'neither'),
#   ((15, 409), 'neither'),
#   ((15, 410), 'neither'),
#   ((14, 410), 'neither'),
#   ((13, 410), 'neither'),
#   ((13, 411), 'neither'),
#   ((12, 411), 'neither'),
#   ((12, 412), 'neither'),
#   ((12, 413), 'neither'),
#   ((12, 414), 'neither'),
#   ((12, 415), 'neither'),
#   ((12, 416), 'neither'),
#   ((12, 417), 'neither'),
#   ((12, 418), 'neither'),
#   ((13, 418), 'neither'),
#   ((13, 419), 'neither'),
#   ((13, 420), 'neither'),
#   ((12, 420), 'neither'),
#   ((12, 421), 'neither'),
#   ((12, 422), 'neither'),
#   ((12, 423), 'neither'),
#   ((12, 424), 'neither'),
#   ((12, 425), 'neither'),
#   ((12, 426), 'neither'),
#   ((12, 427), 'neither'),
#   ((12, 428), 'neither'),
#   ((12, 429), 'neither'),
#   ((13, 429), 'neither'),
#   ((13, 430), 'neither'),
#   ((13, 431), 'neither'),
#   ((13, 432), 'neither'),
#   ((14, 432), 'neither'),
#   ((14, 433), 'neither'),
#   ((14, 434), 'neither'),
#   ((14, 435), 'neither'),
#   ((14, 436), 'neither'),
#   ((13, 436), 'neither'),
#   ((12, 436), 'neither'),
#   ((11, 436), 'neither'),
#   ((11, 437), 'neither'),
#   ((10, 437), 'neither'),
#   ((10, 438), 'neither'),
#   ((10, 439), 'neither'),
#   ((9, 439), 'neither'),
#   ((9, 440), 'neither'),
#   ((9, 441), 'neither'),
#   ((9, 442), 'neither'),
#   ((9, 443), 'neither'),
#   ((9, 444), 'neither'),
#   ((9, 445), 'neither'),
#   ((8, 445), 'neither'),
#   ((8, 446), 'neither'),
#   ((7, 446), 'neither'),
#   ((6, 446), 'neither'),
#   ((5, 446), 'neither'),
#   ((5, 447), 'neither'),
#   ((5, 448), 'neither'),
#   ((6, 448), 'neither'),
#   ((6, 449), 'neither'),
#   ((6, 450), 'neither'),
#   ((6, 451), 'neither'),
#   ((6, 452), 'neither'),
#   ((6, 453), 'neither'),
#   ((6, 454), 'neither'),
#   ((6, 455), 'neither'),
#   ((6, 456), 'neither'),
#   ((7, 456), 'neither'),
#   ((7, 457), 'neither'),
#   ((7, 458), 'neither'),
#   ((7, 459), 'neither'),
#   ((7, 460), 'neither'),
#   ((6, 460), 'neither'),
#   ((5, 460), 'neither'),
#   ((4, 460), 'neither'),
#   ((3, 460), 'neither'),
#   ((3, 461), 'neither'),
#   ((2, 461), 'neither'),
#   ((2, 462), 'neither'),
#   ((2, 463), 'neither'),
#   ((3, 463), 'neither'),
#   ((4, 463), 'neither'),
#   ((4, 464), 'neither'),
#   ((4, 465), 'neither'),
#   ((4, 466), 'neither'),
#   ((4, 467), 'neither'),
#   ((4, 468), 'neither'),
#   ((4, 469), 'neither'),
#   ((4, 470), 'neither'),
#   ((4, 471), 'neither'),
#   ((4, 472), 'neither'),
#   ((3, 472), 'neither'),
#   ((3, 473), 'neither'),
#   ((3, 474), 'neither'),
#   ((2, 474), 'neither'),
#   ((2, 475), 'neither'),
#   ((1, 475), 'neither'),
#   ((1, 476), 'neither'),
#   ((1, 477), 'neither'),
#   ((1, 478), 'neither'),
#   ((1, 479), 'neither'),
#   ((1, 480), 'neither'),
#   ((1, 481), 'neither'),
#   ((1, 482), 'neither'),
#   ((1, 483), 'neither'),
#   ((1, 484), 'neither'),
#   ((0, 484), 'neither'),
#   ((0, 485), 'neither'),
#   ((0, 486), 'neither'),
#   ((0, 487), 'neither'),
#   ((0, 488), 'neither'),
#   ((1, 488), 'neither'),
#   ((1, 489), 'neither'),
#   ((1, 490), 'neither'),
#   ((1, 491), 'neither'),
#   ((1, 492), 'neither'),
#   ((1, 493), 'neither'),
#   ((1, 494), 'neither'),
#   ((2, 494), 'neither'),
#   ((2, 495), 'neither'),
#   ((3, 495), 'neither'),
#   ((3, 496), 'neither'),
#   ((3, 497), 'neither'),
#   ((4, 497), 'neither'),
#   ((5, 497), 'neither'),
#   ((5, 498), 'neither'),
#   ((5, 499), 'neither'),
#   ((5, 500), 'neither'),
#   ((5, 501), 'neither'),
#   ((5, 502), 'neither'),
#   ((5, 503), 'neither'),
#   ((5, 504), 'neither'),
#   ((5, 505), 'neither'),
#   ((5, 506), 'neither'),
#   ((5, 507), 'neither'),
#   ((4, 507), 'neither'),
#   ((3, 507), 'neither'),
#   ((3, 508), 'neither'),
#   ((3, 509), 'neither'),
#   ((3, 510), 'neither'),
#   ((3, 511), 'neither'),
#   ((3, 512), 'neither'),
#   ((3, 513), 'neither'),
#   ((3, 514), 'neither'),
#   ((3, 515), 'neither'),
#   ((3, 516), 'neither'),
#   ((3, 517), 'neither'),
#   ((3, 518), 'neither'),
#   ((3, 519), 'neither'),
#   ((3, 520), 'neither'),
#   ((3, 521), 'neither'),
#   ((4, 521), 'neither'),
#   ((4, 522), 'neither'),
#   ((4, 523), 'neither'),
#   ((5, 523), 'neither'),
#   ((5, 524), 'neither'),
#   ((5, 525), 'neither'),
#   ((4, 525), 'neither'),
#   ((4, 526), 'neither'),
#   ((3, 526), 'neither'),
#   ((3, 527), 'neither'),
#   ((3, 528), 'neither'),
#   ((3, 529), 'neither'),
#   ((3, 530), 'neither'),
#   ((3, 531), 'neither'),
#   ((3, 532), 'neither'),
#   ((3, 533), 'neither'),
#   ((3, 534), 'neither'),
#   ((4, 534), 'neither'),
#   ((4, 535), 'neither'),
#   ((4, 536), 'neither'),
#   ((4, 536), 'climbing gear'),
#   ((5, 536), 'climbing gear'),
#   ((5, 537), 'climbing gear'),
#   ((5, 538), 'climbing gear'),
#   ((5, 539), 'climbing gear'),
#   ((5, 540), 'climbing gear'),
#   ((5, 541), 'climbing gear'),
#   ((5, 542), 'climbing gear'),
#   ((5, 543), 'climbing gear'),
#   ((5, 544), 'climbing gear'),
#   ((5, 545), 'climbing gear'),
#   ((5, 546), 'climbing gear'),
#   ((5, 547), 'climbing gear'),
#   ((5, 548), 'climbing gear'),
#   ((5, 549), 'climbing gear'),
#   ((6, 549), 'climbing gear'),
#   ((6, 550), 'climbing gear'),
#   ((7, 550), 'climbing gear'),
#   ((8, 550), 'climbing gear'),
#   ((8, 551), 'climbing gear'),
#   ((8, 552), 'climbing gear'),
#   ((8, 553), 'climbing gear'),
#   ((7, 553), 'climbing gear'),
#   ((7, 554), 'climbing gear'),
#   ((7, 555), 'climbing gear'),
#   ((7, 556), 'climbing gear'),
#   ((8, 556), 'climbing gear'),
#   ((9, 556), 'climbing gear'),
#   ((9, 557), 'climbing gear'),
#   ((9, 558), 'climbing gear'),
#   ((9, 559), 'climbing gear'),
#   ((9, 560), 'climbing gear'),
#   ((9, 561), 'climbing gear'),
#   ((9, 562), 'climbing gear'),
#   ((8, 562), 'climbing gear'),
#   ((8, 563), 'climbing gear'),
#   ((8, 564), 'climbing gear'),
#   ((8, 565), 'climbing gear'),
#   ((9, 565), 'climbing gear'),
#   ((9, 566), 'climbing gear'),
#   ((9, 567), 'climbing gear'),
#   ((10, 567), 'climbing gear'),
#   ((10, 568), 'climbing gear'),
#   ((11, 568), 'climbing gear'),
#   ((12, 568), 'climbing gear'),
#   ((13, 568), 'climbing gear'),
#   ((13, 569), 'climbing gear'),
#   ((14, 569), 'climbing gear'),
#   ((14, 570), 'climbing gear'),
#   ((14, 571), 'climbing gear'),
#   ((14, 572), 'climbing gear'),
#   ((14, 573), 'climbing gear'),
#   ((14, 574), 'climbing gear'),
#   ((14, 575), 'climbing gear'),
#   ((14, 576), 'climbing gear'),
#   ((14, 577), 'climbing gear'),
#   ((14, 578), 'climbing gear'),
#   ((14, 579), 'climbing gear'),
#   ((13, 579), 'climbing gear'),
#   ((13, 580), 'climbing gear'),
#   ((13, 581), 'climbing gear'),
#   ((13, 582), 'climbing gear'),
#   ((13, 583), 'climbing gear'),
#   ((13, 584), 'climbing gear'),
#   ((13, 585), 'climbing gear'),
#   ((13, 586), 'climbing gear'),
#   ((14, 586), 'climbing gear'),
#   ((14, 587), 'climbing gear'),
#   ((14, 588), 'climbing gear'),
#   ((14, 589), 'climbing gear'),
#   ((14, 590), 'climbing gear'),
#   ((14, 591), 'climbing gear'),
#   ((14, 592), 'climbing gear'),
#   ((15, 592), 'climbing gear'),
#   ((15, 593), 'climbing gear'),
#   ((15, 594), 'climbing gear'),
#   ((15, 595), 'climbing gear'),
#   ((15, 596), 'climbing gear'),
#   ((14, 596), 'climbing gear'),
#   ((14, 597), 'climbing gear'),
#   ((14, 598), 'climbing gear'),
#   ((13, 598), 'climbing gear'),
#   ((12, 598), 'climbing gear'),
#   ((12, 599), 'climbing gear'),
#   ((12, 600), 'climbing gear'),
#   ((12, 601), 'climbing gear'),
#   ((12, 602), 'climbing gear'),
#   ((12, 603), 'climbing gear'),
#   ((12, 603), 'torch'),
#   ((12, 604), 'torch'),
#   ((12, 605), 'torch'),
#   ((12, 606), 'torch'),
#   ((12, 607), 'torch'),
#   ((12, 608), 'torch'),
#   ((13, 608), 'torch'),
#   ((13, 609), 'torch'),
#   ((13, 610), 'torch'),
#   ((13, 611), 'torch'),
#   ((13, 612), 'torch'),
#   ((13, 613), 'torch'),
#   ((12, 613), 'torch'),
#   ((12, 614), 'torch'),
#   ((12, 615), 'torch'),
#   ((12, 616), 'torch'),
#   ((12, 617), 'torch'),
#   ((11, 617), 'torch'),
#   ((11, 618), 'torch'),
#   ((11, 619), 'torch'),
#   ((11, 620), 'torch'),
#   ((11, 621), 'torch'),
#   ((11, 622), 'torch'),
#   ((11, 623), 'torch'),
#   ((11, 624), 'torch'),
#   ((11, 625), 'torch'),
#   ((11, 626), 'torch'),
#   ((11, 627), 'torch'),
#   ((11, 628), 'torch'),
#   ((11, 629), 'torch'),
#   ((11, 630), 'torch'),
#   ((11, 631), 'torch'),
#   ((11, 632), 'torch'),
#   ((11, 633), 'torch'),
#   ((11, 634), 'torch'),
#   ((12, 634), 'torch'),
#   ((13, 634), 'torch'),
#   ((13, 635), 'torch'),
#   ((13, 636), 'torch'),
#   ((13, 637), 'torch'),
#   ((13, 638), 'torch'),
#   ((13, 639), 'torch'),
#   ((13, 640), 'torch'),
#   ((13, 641), 'torch'),
#   ((13, 642), 'torch'),
#   ((13, 643), 'torch'),
#   ((13, 644), 'torch'),
#   ((13, 645), 'torch'),
#   ((13, 646), 'torch'),
#   ((13, 647), 'torch'),
#   ((13, 648), 'torch'),
#   ((13, 648), 'climbing gear'),
#   ((13, 649), 'climbing gear'),
#   ((14, 649), 'climbing gear'),
#   ((14, 650), 'climbing gear'),
#   ((14, 651), 'climbing gear'),
#   ((14, 652), 'climbing gear'),
#   ((14, 653), 'climbing gear'),
#   ((14, 654), 'climbing gear'),
#   ((14, 655), 'climbing gear'),
#   ((14, 656), 'climbing gear'),
#   ((14, 657), 'climbing gear'),
#   ((14, 658), 'climbing gear'),
#   ((14, 659), 'climbing gear'),
#   ((14, 660), 'climbing gear'),
#   ((14, 661), 'climbing gear'),
#   ((14, 662), 'climbing gear'),
#   ((14, 663), 'climbing gear'),
#   ((14, 664), 'climbing gear'),
#   ((14, 665), 'climbing gear'),
#   ((14, 666), 'climbing gear'),
#   ((13, 666), 'climbing gear'),
#   ((13, 667), 'climbing gear'),
#   ((13, 668), 'climbing gear'),
#   ((13, 669), 'climbing gear'),
#   ((13, 670), 'climbing gear'),
#   ((14, 670), 'climbing gear'),
#   ((14, 671), 'climbing gear'),
#   ((14, 672), 'climbing gear'),
#   ((14, 673), 'climbing gear'),
#   ((15, 673), 'climbing gear'),
#   ((15, 674), 'climbing gear'),
#   ((15, 675), 'climbing gear'),
#   ((15, 676), 'climbing gear'),
#   ((15, 677), 'climbing gear'),
#   ((15, 678), 'climbing gear'),
#   ((16, 678), 'climbing gear'),
#   ((17, 678), 'climbing gear'),
#   ((18, 678), 'climbing gear'),
#   ((19, 678), 'climbing gear'),
#   ((19, 679), 'climbing gear'),
#   ((19, 680), 'climbing gear'),
#   ((19, 681), 'climbing gear'),
#   ((19, 682), 'climbing gear'),
#   ((19, 683), 'climbing gear'),
#   ((20, 683), 'climbing gear'),
#   ((20, 684), 'climbing gear'),
#   ((20, 685), 'climbing gear'),
#   ((20, 686), 'climbing gear'),
#   ((19, 686), 'climbing gear'),
#   ((18, 686), 'climbing gear'),
#   ((18, 687), 'climbing gear'),
#   ((18, 688), 'climbing gear'),
#   ((18, 689), 'climbing gear'),
#   ((19, 689), 'climbing gear'),
#   ((19, 690), 'climbing gear'),
#   ((19, 691), 'climbing gear'),
#   ((19, 692), 'climbing gear'),
#   ((18, 692), 'climbing gear'),
#   ((18, 693), 'climbing gear'),
#   ((18, 694), 'climbing gear'),
#   ((18, 695), 'climbing gear'),
#   ((18, 696), 'climbing gear'),
#   ((17, 696), 'climbing gear'),
#   ((16, 696), 'climbing gear'),
#   ((16, 697), 'climbing gear'),
#   ((16, 698), 'climbing gear'),
#   ((17, 698), 'climbing gear'),
#   ((17, 699), 'climbing gear'),
#   ((17, 700), 'climbing gear'),
#   ((17, 701), 'climbing gear'),
#   ((17, 702), 'climbing gear'),
#   ((17, 703), 'climbing gear'),
#   ((16, 703), 'climbing gear'),
#   ((16, 704), 'climbing gear'),
#   ((16, 705), 'climbing gear'),
#   ((16, 706), 'climbing gear'),
#   ((15, 706), 'climbing gear'),
#   ((15, 707), 'climbing gear'),
#   ((15, 708), 'climbing gear'),
#   ((15, 709), 'climbing gear'),
#   ((15, 710), 'climbing gear'),
#   ((15, 711), 'climbing gear'),
#   ((15, 712), 'climbing gear'),
#   ((15, 713), 'climbing gear'),
#   ((15, 714), 'climbing gear'),
#   ((15, 715), 'climbing gear'),
#   ((15, 716), 'climbing gear'),
#   ((14, 716), 'climbing gear'),
#   ((13, 716), 'climbing gear'),
#   ((13, 717), 'climbing gear'),
#   ((13, 718), 'climbing gear'),
#   ((13, 719), 'climbing gear'),
#   ((13, 720), 'climbing gear'),
#   ((12, 720), 'climbing gear'),
#   ((12, 721), 'climbing gear'),
#   ((12, 722), 'climbing gear'),
#   ((11, 722), 'climbing gear'),
#   ((11, 722), 'torch')])

# %% [markdown]
# That's a suspiciously neat number but turns out to be correct.
