# %% [markdown]
# ## Day 24: Immune System Simulator 20XX
#
# https://adventofcode.com/2018/day/24
#
# ### Part 1
#
# This looks tedious and frustrating but I'm not giving up this close to the end.

# %%
from parse import parse
from collections import namedtuple
from pyrsistent import pmap, pset


Group = namedtuple('Group', 'id type units hit_points immune weak attack_points damage_type initiative')


def parse_system(data):
    groups = pmap()
    
    lines = [line.strip() for line in data.strip().splitlines()]
    
    type_parsing = 'immune'
    group_id = 0
    
    parse_string = '{n:d} units each with {hp:d} hit points{immune_weak}with an attack that does {ap:d} {damage_type} damage at initiative {initiative:d}'
    
    for line in lines[1:]:
        if line == 'Infection:':
            type_parsing = 'infection'
        else:
            p = parse(parse_string, line)
            
            if p:
                weak = pset()
                immune = pset()
                iws = p['immune_weak'].strip().strip('()').split(';')

                for iw in iws:
                    if iw:
                        words = iw.split()
                        damage_types = pset([s.strip(',') for s in words[2:]])
                        if words[0] == 'immune':
                            immune = damage_types
                        else:
                            weak = damage_types
                        
                groups = groups.set(group_id, 
                                    Group(group_id, type_parsing, p['n'], p['hp'], 
                                          immune, weak, p['ap'], p['damage_type'], 
                                          p['initiative']))
                group_id += 1

    return groups

# %%
test_data = '''Immune System:
17 units each with 5390 hit points (weak to radiation, bludgeoning) with an attack that does 4507 fire damage at initiative 2
989 units each with 1274 hit points (immune to fire; weak to bludgeoning, slashing) with an attack that does 25 slashing damage at initiative 3

Infection:
801 units each with 4706 hit points (weak to radiation) with an attack that does 116 bludgeoning damage at initiative 1
4485 units each with 2961 hit points (immune to radiation; weak to fire, cold) with an attack that does 12 slashing damage at initiative 4'''

test_groups = parse_system(test_data)
test_groups
# Out:
# pmap({0: Group(id=0, type='immune', units=17, hit_points=5390, immune=pset(), weak=pset(['bludgeoning', 'radiation']), attack_points=4507, damage_type='fire', initiative=2), 1: Group(id=1, type='immune', units=989, hit_points=1274, immune=pset(['fire']), weak=pset(['slashing', 'bludgeoning']), attack_points=25, damage_type='slashing', initiative=3), 2: Group(id=2, type='infection', units=801, hit_points=4706, immune=pset(), weak=pset(['radiation']), attack_points=116, damage_type='bludgeoning', initiative=1), 3: Group(id=3, type='infection', units=4485, hit_points=2961, immune=pset(['radiation']), weak=pset(['cold', 'fire']), attack_points=12, damage_type='slashing', initiative=4)})

# %%
def damage(attacker, defender):
    if attacker.damage_type in defender.immune:
        return 0
    elif attacker.damage_type in defender.weak:
        return 2 * attacker.units * attacker.attack_points
    else: 
        return attacker.units * attacker.attack_points
    
    
def target_selection(groups, debug=False):
    targets = pmap()
    
    attackers = sorted(groups,
                       key = lambda g: (groups[g].units * groups[g].attack_points,
                                        groups[g].initiative),
                       reverse=True)
    attacked = pset()
    
    for attack_id in attackers:
        attacker = groups[attack_id]
        
        defenders = [groups[d] 
                     for d in groups 
                     if groups[d].type != attacker.type 
                     and groups[d].id not in attacked]
        
        if defenders:
            if debug:
                for defender in sorted(defenders, key=lambda d: d.id):
                    # This is clumsy, for debugging
                    d = damage(attacker, defender)
                t = 'Immune System' if attacker.type == 'immune' else 'Infection'
                print(f'{t} group {attacker.id} would deal defending group {defender.id} {d} damage')

            selected = max(defenders, 
                           key=lambda d: (damage(attacker, d),
                                          d.units * d.attack_points,
                                          d.initiative))
            if damage(attacker, selected) > 0:
                targets = targets.set(attack_id, pset([selected.id]))
                attacked = attacked.add(selected.id)
            else:
                targets = targets.set(attack_id, pset())
        else: 
            targets = targets.set(attack_id, pset())
    
    return targets

# %%
target_selection(test_groups, debug=True)
# Out:
# Infection group 2 would deal defending group 1 185832 damage
# Immune System group 0 would deal defending group 3 153238 damage
# Infection group 3 would deal defending group 1 107640 damage
# Immune System group 1 would deal defending group 2 24725 damage
# pmap({0: pset([3]), 1: pset([2]), 2: pset([0]), 3: pset([1])})

# %%
def attack(groups, attack_id, defend_id, debug=False):
    if attack_id in groups and defend_id in groups:
        attacker = groups[attack_id]
        defender = groups[defend_id]

        d = damage(attacker, defender)
        kills = min(d // defender.hit_points, defender.units)
        defender = defender._replace(units = defender.units - kills)
        
        if debug:
            att_t = 'Immune System' if attacker.type == 'immune' else 'Infection'
            print(f'{att_t} group {attack_id} attacks defending group {defend_id}, killing {kills} units')
        if defender.units > 0:
            return groups.set(defend_id, defender)
        else:
            return groups.discard(defend_id)
    else:
        return groups
    

def fight(groups, debug=False):
    targets = target_selection(groups, debug)
    
    if debug:
        print()

    for attack_id in sorted(targets,
                            key=lambda g: groups[g].initiative,
                            reverse=True):
        for defend_id in targets[attack_id]:
            groups = attack(groups, attack_id, defend_id, debug)
        
    return groups
        
        
fight(test_groups, debug=True)
# Out:
# Infection group 2 would deal defending group 1 185832 damage
# Immune System group 0 would deal defending group 3 153238 damage
# Infection group 3 would deal defending group 1 107640 damage
# Immune System group 1 would deal defending group 2 24725 damage
#
# Infection group 3 attacks defending group 1, killing 84 units
# Immune System group 1 attacks defending group 2, killing 4 units
# Immune System group 0 attacks defending group 3, killing 51 units
# Infection group 2 attacks defending group 0, killing 17 units
# pmap({1: Group(id=1, type='immune', units=905, hit_points=1274, immune=pset(['fire']), weak=pset(['slashing', 'bludgeoning']), attack_points=25, damage_type='slashing', initiative=3), 2: Group(id=2, type='infection', units=797, hit_points=4706, immune=pset(), weak=pset(['radiation']), attack_points=116, damage_type='bludgeoning', initiative=1), 3: Group(id=3, type='infection', units=4434, hit_points=2961, immune=pset(['radiation']), weak=pset(['cold', 'fire']), attack_points=12, damage_type='slashing', initiative=4)})

# %%
def print_groups(groups):
    print('Immune System:')
    imm_ids = [i for i in groups if groups[i].type == 'immune']
    if imm_ids:
        for i in sorted(imm_ids):
            print(f'Group {i} contains {groups[i].units} units')
    else:
        print('No groups remain')
        
    print('Infection:')
    inf_ids = [i for i in groups if groups[i].type == 'infection']
    if inf_ids:
        for i in sorted(inf_ids):
            print(f'Group {i} contains {groups[i].units} units')
    else:
        print('No groups remain') 
    

def battle(groups, debug=False):
    while any(True for g in groups if groups[g].type == 'immune') and \
        any(True for g in groups if groups[g].type == 'infection'):
        if debug:
            print_groups(groups)
            print()
        groups = fight(groups, debug)
        
    if debug:
        print()
        print_groups(groups)
        
    return sum(groups[g].units for g in groups)

# %%
battle(test_groups, debug=True)
# Out:
# Immune System:
# Group 0 contains 17 units
# Group 1 contains 989 units
# Infection:
# Group 2 contains 801 units
# Group 3 contains 4485 units
#
# Infection group 2 would deal defending group 1 185832 damage
# Immune System group 0 would deal defending group 3 153238 damage
# Infection group 3 would deal defending group 1 107640 damage
# Immune System group 1 would deal defending group 2 24725 damage
#
# Infection group 3 attacks defending group 1, killing 84 units
# Immune System group 1 attacks defending group 2, killing 4 units
# Immune System group 0 attacks defending group 3, killing 51 units
# Infection group 2 attacks defending group 0, killing 17 units
# Immune System:
# Group 1 contains 905 units
# Infection:
# Group 2 contains 797 units
# Group 3 contains 4434 units
#
# Infection group 2 would deal defending group 1 184904 damage
# Immune System group 1 would deal defending group 3 22625 damage
#
# Immune System group 1 attacks defending group 2, killing 4 units
# Infection group 2 attacks defending group 1, killing 144 units
# Immune System:
# Group 1 contains 761 units
# Infection:
# Group 2 contains 793 units
# Group 3 contains 4434 units
#
# Infection group 2 would deal defending group 1 183976 damage
# Immune System group 1 would deal defending group 3 19025 damage
#
# Immune System group 1 attacks defending group 2, killing 4 units
# Infection group 2 attacks defending group 1, killing 143 units
# Immune System:
# Group 1 contains 618 units
# Infection:
# Group 2 contains 789 units
# Group 3 contains 4434 units
#
# Infection group 2 would deal defending group 1 183048 damage
# Immune System group 1 would deal defending group 3 15450 damage
#
# Immune System group 1 attacks defending group 2, killing 3 units
# Infection group 2 attacks defending group 1, killing 143 units
# Immune System:
# Group 1 contains 475 units
# Infection:
# Group 2 contains 786 units
# Group 3 contains 4434 units
#
# Infection group 2 would deal defending group 1 182352 damage
# Immune System group 1 would deal defending group 3 11875 damage
#
# Immune System group 1 attacks defending group 2, killing 2 units
# Infection group 2 attacks defending group 1, killing 142 units
# Immune System:
# Group 1 contains 333 units
# Infection:
# Group 2 contains 784 units
# Group 3 contains 4434 units
#
# Infection group 2 would deal defending group 1 181888 damage
# Immune System group 1 would deal defending group 3 8325 damage
#
# Immune System group 1 attacks defending group 2, killing 1 units
# Infection group 2 attacks defending group 1, killing 142 units
# Immune System:
# Group 1 contains 191 units
# Infection:
# Group 2 contains 783 units
# Group 3 contains 4434 units
#
# Infection group 2 would deal defending group 1 181656 damage
# Immune System group 1 would deal defending group 3 4775 damage
#
# Immune System group 1 attacks defending group 2, killing 1 units
# Infection group 2 attacks defending group 1, killing 142 units
# Immune System:
# Group 1 contains 49 units
# Infection:
# Group 2 contains 782 units
# Group 3 contains 4434 units
#
# Infection group 2 would deal defending group 1 181424 damage
# Immune System group 1 would deal defending group 3 1225 damage
#
# Immune System group 1 attacks defending group 2, killing 0 units
# Infection group 2 attacks defending group 1, killing 49 units
#
# Immune System:
# No groups remain
# Infection:
# Group 2 contains 782 units
# Group 3 contains 4434 units
# 5216

# %% [markdown]
# It works for the test data, now to have my day ruined by edge cases on the problem data.

# %%
groups = parse_system(open('input', 'r').read())
# %time battle(groups)
# Out:
# CPU times: user 780 ms, sys: 0 ns, total: 780 ms
# Wall time: 780 ms
# 33551

# %% [markdown]
# It did, I wasn't tie-breaking when selecting which opponent to attack, but that was spotted thankfully quickly.
#
# ### Part 2

# %%
def boost(groups, n):
    for g in groups:
        if groups[g].type == 'immune':
            groups = groups.set(g, 
                                groups[g]._replace(attack_points = groups[g].attack_points + n))
            
    return groups
            
boost(test_groups, 1570)
# Out:
# pmap({0: Group(id=0, type='immune', units=17, hit_points=5390, immune=pset(), weak=pset(['bludgeoning', 'radiation']), attack_points=6077, damage_type='fire', initiative=2), 1: Group(id=1, type='immune', units=989, hit_points=1274, immune=pset(['fire']), weak=pset(['slashing', 'bludgeoning']), attack_points=1595, damage_type='slashing', initiative=3), 2: Group(id=2, type='infection', units=801, hit_points=4706, immune=pset(), weak=pset(['radiation']), attack_points=116, damage_type='bludgeoning', initiative=1), 3: Group(id=3, type='infection', units=4485, hit_points=2961, immune=pset(['radiation']), weak=pset(['cold', 'fire']), attack_points=12, damage_type='slashing', initiative=4)})

# %%
def battle_winner(groups, debug=False):
    while any(True for g in groups if groups[g].type == 'immune') and \
        any(True for g in groups if groups[g].type == 'infection'):
        if debug:
            print_groups(groups)
            print()
        old_groups = groups
        groups = fight(groups, debug)
        if groups == old_groups:
            return 'draw', groups
        
    if debug:
        print()
        print_groups(groups)
        
    if any(True for g in groups if groups[g].type == 'immune'):
        return 'immune', groups
    else:
        return 'infection', groups
    

battle_winner(boost(test_groups, 1570), debug=True)
# Out:
# Immune System:
# Group 0 contains 17 units
# Group 1 contains 989 units
# Infection:
# Group 2 contains 801 units
# Group 3 contains 4485 units
#
# Immune System group 1 would deal defending group 3 1577455 damage
# Immune System group 0 would deal defending group 3 206618 damage
# Infection group 2 would deal defending group 1 185832 damage
# Infection group 3 would deal defending group 0 53820 damage
#
# Infection group 3 attacks defending group 0, killing 9 units
# Immune System group 1 attacks defending group 2, killing 335 units
# Immune System group 0 attacks defending group 3, killing 32 units
# Infection group 2 attacks defending group 1, killing 84 units
# Immune System:
# Group 0 contains 8 units
# Group 1 contains 905 units
# Infection:
# Group 2 contains 466 units
# Group 3 contains 4453 units
#
# Immune System group 1 would deal defending group 3 1443475 damage
# Infection group 2 would deal defending group 1 108112 damage
# Infection group 3 would deal defending group 0 53436 damage
# Immune System group 0 would deal defending group 3 97232 damage
#
# Infection group 3 attacks defending group 0, killing 8 units
# Immune System group 1 attacks defending group 2, killing 306 units
# Infection group 2 attacks defending group 1, killing 29 units
# Immune System:
# Group 1 contains 876 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 4453 units
#
# Immune System group 1 would deal defending group 3 1397220 damage
# Infection group 3 would deal defending group 1 106872 damage
#
# Infection group 3 attacks defending group 1, killing 83 units
# Immune System group 1 attacks defending group 3, killing 427 units
# Immune System:
# Group 1 contains 793 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 4026 units
#
# Immune System group 1 would deal defending group 3 1264835 damage
# Infection group 3 would deal defending group 1 96624 damage
#
# Infection group 3 attacks defending group 1, killing 75 units
# Immune System group 1 attacks defending group 3, killing 386 units
# Immune System:
# Group 1 contains 718 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 3640 units
#
# Immune System group 1 would deal defending group 3 1145210 damage
# Infection group 3 would deal defending group 1 87360 damage
#
# Infection group 3 attacks defending group 1, killing 68 units
# Immune System group 1 attacks defending group 3, killing 350 units
# Immune System:
# Group 1 contains 650 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 3290 units
#
# Immune System group 1 would deal defending group 3 1036750 damage
# Infection group 3 would deal defending group 1 78960 damage
#
# Infection group 3 attacks defending group 1, killing 61 units
# Immune System group 1 attacks defending group 3, killing 317 units
# Immune System:
# Group 1 contains 589 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 2973 units
#
# Immune System group 1 would deal defending group 3 939455 damage
# Infection group 3 would deal defending group 1 71352 damage
#
# Infection group 3 attacks defending group 1, killing 56 units
# Immune System group 1 attacks defending group 3, killing 287 units
# Immune System:
# Group 1 contains 533 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 2686 units
#
# Immune System group 1 would deal defending group 3 850135 damage
# Infection group 3 would deal defending group 1 64464 damage
#
# Infection group 3 attacks defending group 1, killing 50 units
# Immune System group 1 attacks defending group 3, killing 260 units
# Immune System:
# Group 1 contains 483 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 2426 units
#
# Immune System group 1 would deal defending group 3 770385 damage
# Infection group 3 would deal defending group 1 58224 damage
#
# Infection group 3 attacks defending group 1, killing 45 units
# Immune System group 1 attacks defending group 3, killing 235 units
# Immune System:
# Group 1 contains 438 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 2191 units
#
# Immune System group 1 would deal defending group 3 698610 damage
# Infection group 3 would deal defending group 1 52584 damage
#
# Infection group 3 attacks defending group 1, killing 41 units
# Immune System group 1 attacks defending group 3, killing 213 units
# Immune System:
# Group 1 contains 397 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 1978 units
#
# Immune System group 1 would deal defending group 3 633215 damage
# Infection group 3 would deal defending group 1 47472 damage
#
# Infection group 3 attacks defending group 1, killing 37 units
# Immune System group 1 attacks defending group 3, killing 193 units
# Immune System:
# Group 1 contains 360 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 1785 units
#
# Immune System group 1 would deal defending group 3 574200 damage
# Infection group 3 would deal defending group 1 42840 damage
#
# Infection group 3 attacks defending group 1, killing 33 units
# Immune System group 1 attacks defending group 3, killing 176 units
# Immune System:
# Group 1 contains 327 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 1609 units
#
# Immune System group 1 would deal defending group 3 521565 damage
# Infection group 3 would deal defending group 1 38616 damage
#
# Infection group 3 attacks defending group 1, killing 30 units
# Immune System group 1 attacks defending group 3, killing 159 units
# Immune System:
# Group 1 contains 297 units
# Infection:
# Group 2 contains 160 units
# Group 3 contains 1450 units
#
# Immune System group 1 would deal defending group 3 473715 damage
# Infection group 2 would deal defending group 1 37120 damage
#
# Immune System group 1 attacks defending group 2, killing 100 units
# Infection group 2 attacks defending group 1, killing 10 units
# Immune System:
# Group 1 contains 287 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 1450 units
#
# Immune System group 1 would deal defending group 3 457765 damage
# Infection group 3 would deal defending group 1 34800 damage
#
# Infection group 3 attacks defending group 1, killing 27 units
# Immune System group 1 attacks defending group 3, killing 140 units
# Immune System:
# Group 1 contains 260 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 1310 units
#
# Immune System group 1 would deal defending group 3 414700 damage
# Infection group 3 would deal defending group 1 31440 damage
#
# Infection group 3 attacks defending group 1, killing 24 units
# Immune System group 1 attacks defending group 3, killing 127 units
# Immune System:
# Group 1 contains 236 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 1183 units
#
# Immune System group 1 would deal defending group 3 376420 damage
# Infection group 3 would deal defending group 1 28392 damage
#
# Infection group 3 attacks defending group 1, killing 22 units
# Immune System group 1 attacks defending group 3, killing 115 units
# Immune System:
# Group 1 contains 214 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 1068 units
#
# Immune System group 1 would deal defending group 3 341330 damage
# Infection group 3 would deal defending group 1 25632 damage
#
# Infection group 3 attacks defending group 1, killing 20 units
# Immune System group 1 attacks defending group 3, killing 104 units
# Immune System:
# Group 1 contains 194 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 964 units
#
# Immune System group 1 would deal defending group 3 309430 damage
# Infection group 3 would deal defending group 1 23136 damage
#
# Infection group 3 attacks defending group 1, killing 18 units
# Immune System group 1 attacks defending group 3, killing 94 units
# Immune System:
# Group 1 contains 176 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 870 units
#
# Immune System group 1 would deal defending group 3 280720 damage
# Infection group 3 would deal defending group 1 20880 damage
#
# Infection group 3 attacks defending group 1, killing 16 units
# Immune System group 1 attacks defending group 3, killing 86 units
# Immune System:
# Group 1 contains 160 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 784 units
#
# Immune System group 1 would deal defending group 3 255200 damage
# Infection group 3 would deal defending group 1 18816 damage
#
# Infection group 3 attacks defending group 1, killing 14 units
# Immune System group 1 attacks defending group 3, killing 78 units
# Immune System:
# Group 1 contains 146 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 706 units
#
# Immune System group 1 would deal defending group 3 232870 damage
# Infection group 3 would deal defending group 1 16944 damage
#
# Infection group 3 attacks defending group 1, killing 13 units
# Immune System group 1 attacks defending group 3, killing 71 units
# Immune System:
# Group 1 contains 133 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 635 units
#
# Immune System group 1 would deal defending group 3 212135 damage
# Infection group 3 would deal defending group 1 15240 damage
#
# Infection group 3 attacks defending group 1, killing 11 units
# Immune System group 1 attacks defending group 3, killing 65 units
# Immune System:
# Group 1 contains 122 units
# Infection:
# Group 2 contains 60 units
# Group 3 contains 570 units
#
# Immune System group 1 would deal defending group 3 194590 damage
# Infection group 2 would deal defending group 1 13920 damage
#
# Immune System group 1 attacks defending group 2, killing 41 units
# Infection group 2 attacks defending group 1, killing 3 units
# Immune System:
# Group 1 contains 119 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 570 units
#
# Immune System group 1 would deal defending group 3 189805 damage
# Infection group 3 would deal defending group 1 13680 damage
#
# Infection group 3 attacks defending group 1, killing 10 units
# Immune System group 1 attacks defending group 3, killing 58 units
# Immune System:
# Group 1 contains 109 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 512 units
#
# Immune System group 1 would deal defending group 3 173855 damage
# Infection group 3 would deal defending group 1 12288 damage
#
# Infection group 3 attacks defending group 1, killing 9 units
# Immune System group 1 attacks defending group 3, killing 53 units
# Immune System:
# Group 1 contains 100 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 459 units
#
# Immune System group 1 would deal defending group 3 159500 damage
# Infection group 3 would deal defending group 1 11016 damage
#
# Infection group 3 attacks defending group 1, killing 8 units
# Immune System group 1 attacks defending group 3, killing 49 units
# Immune System:
# Group 1 contains 92 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 410 units
#
# Immune System group 1 would deal defending group 3 146740 damage
# Infection group 3 would deal defending group 1 9840 damage
#
# Infection group 3 attacks defending group 1, killing 7 units
# Immune System group 1 attacks defending group 3, killing 45 units
# Immune System:
# Group 1 contains 85 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 365 units
#
# Immune System group 1 would deal defending group 3 135575 damage
# Infection group 3 would deal defending group 1 8760 damage
#
# Infection group 3 attacks defending group 1, killing 6 units
# Immune System group 1 attacks defending group 3, killing 42 units
# Immune System:
# Group 1 contains 79 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 323 units
#
# Immune System group 1 would deal defending group 3 126005 damage
# Infection group 3 would deal defending group 1 7752 damage
#
# Infection group 3 attacks defending group 1, killing 6 units
# Immune System group 1 attacks defending group 3, killing 39 units
# Immune System:
# Group 1 contains 73 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 284 units
#
# Immune System group 1 would deal defending group 3 116435 damage
# Infection group 3 would deal defending group 1 6816 damage
#
# Infection group 3 attacks defending group 1, killing 5 units
# Immune System group 1 attacks defending group 3, killing 36 units
# Immune System:
# Group 1 contains 68 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 248 units
#
# Immune System group 1 would deal defending group 3 108460 damage
# Infection group 3 would deal defending group 1 5952 damage
#
# Infection group 3 attacks defending group 1, killing 4 units
# Immune System group 1 attacks defending group 3, killing 34 units
# Immune System:
# Group 1 contains 64 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 214 units
#
# Immune System group 1 would deal defending group 3 102080 damage
# Infection group 3 would deal defending group 1 5136 damage
#
# Infection group 3 attacks defending group 1, killing 4 units
# Immune System group 1 attacks defending group 3, killing 32 units
# Immune System:
# Group 1 contains 60 units
# Infection:
# Group 2 contains 19 units
# Group 3 contains 182 units
#
# Immune System group 1 would deal defending group 3 95700 damage
# Infection group 2 would deal defending group 1 4408 damage
#
# Immune System group 1 attacks defending group 2, killing 19 units
# Immune System:
# Group 1 contains 60 units
# Infection:
# Group 3 contains 182 units
#
# Immune System group 1 would deal defending group 3 95700 damage
# Infection group 3 would deal defending group 1 4368 damage
#
# Infection group 3 attacks defending group 1, killing 3 units
# Immune System group 1 attacks defending group 3, killing 30 units
# Immune System:
# Group 1 contains 57 units
# Infection:
# Group 3 contains 152 units
#
# Immune System group 1 would deal defending group 3 90915 damage
# Infection group 3 would deal defending group 1 3648 damage
#
# Infection group 3 attacks defending group 1, killing 2 units
# Immune System group 1 attacks defending group 3, killing 29 units
# Immune System:
# Group 1 contains 55 units
# Infection:
# Group 3 contains 123 units
#
# Immune System group 1 would deal defending group 3 87725 damage
# Infection group 3 would deal defending group 1 2952 damage
#
# Infection group 3 attacks defending group 1, killing 2 units
# Immune System group 1 attacks defending group 3, killing 28 units
# Immune System:
# Group 1 contains 53 units
# Infection:
# Group 3 contains 95 units
#
# Immune System group 1 would deal defending group 3 84535 damage
# Infection group 3 would deal defending group 1 2280 damage
#
# Infection group 3 attacks defending group 1, killing 1 units
# Immune System group 1 attacks defending group 3, killing 28 units
# Immune System:
# Group 1 contains 52 units
# Infection:
# Group 3 contains 67 units
#
# Immune System group 1 would deal defending group 3 82940 damage
# Infection group 3 would deal defending group 1 1608 damage
#
# Infection group 3 attacks defending group 1, killing 1 units
# Immune System group 1 attacks defending group 3, killing 27 units
# Immune System:
# Group 1 contains 51 units
# Infection:
# Group 3 contains 40 units
#
# Immune System group 1 would deal defending group 3 81345 damage
# Infection group 3 would deal defending group 1 960 damage
#
# Infection group 3 attacks defending group 1, killing 0 units
# Immune System group 1 attacks defending group 3, killing 27 units
# Immune System:
# Group 1 contains 51 units
# Infection:
# Group 3 contains 13 units
#
# Immune System group 1 would deal defending group 3 81345 damage
# Infection group 3 would deal defending group 1 312 damage
#
# Infection group 3 attacks defending group 1, killing 0 units
# Immune System group 1 attacks defending group 3, killing 13 units
#
# Immune System:
# Group 1 contains 51 units
# Infection:
# No groups remain
# ('immune',
#  pmap({1: Group(id=1, type='immune', units=51, hit_points=1274, immune=pset(['fire']), weak=pset(['slashing', 'bludgeoning']), attack_points=1595, damage_type='slashing', initiative=3)}))

# %% [markdown]
# A binary search would be a good idea here but I'm lazy so will iterate by hand.

# %%
stopped = False
n = 0
while not stopped:
    winner, remainder = battle_winner(boost(groups, n))
    if winner == 'immune':
        print(n)
        stopped = True
    n += 1000
# Out:
# 1000

# %%
stopped = False
n = 0
while not stopped:
    winner, remainder = battle_winner(boost(groups, n))
    if winner == 'immune':
        print(n)
        stopped = True
    n += 100
# Out:
# 100

# %%
stopped = False
n = 0
while not stopped:
    winner, remainder = battle_winner(boost(groups, n))
    if winner == 'immune':
        print(n)
        stopped = True
    n += 10
# Out:
# 80

# %%
stopped = False
n = 61
while not stopped:
    winner, remainder = battle_winner(boost(groups, n))
    if winner == 'immune':
        print(n)
        stopped = True
    n += 1
# Out:
# 77

# %%
sum(g.units for g in remainder.values())
# Out:
# 760

# %% [markdown]
# I am not proud of this.
